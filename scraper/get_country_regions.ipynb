# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
regions_level2 = gpd.read_file("../france_boundary/gadm36_FRA_2.shp")
regions_level2.head()
# Out:
#   GID_0  NAME_0    GID_1                NAME_1 NL_NAME_1      GID_2   NAME_2  \
# 0   FRA  France  FRA.1_1  Auvergne-Rhône-Alpes      None  FRA.1.1_1      Ain
# 1   FRA  France  FRA.1_1  Auvergne-Rhône-Alpes      None  FRA.1.2_1   Allier
# 2   FRA  France  FRA.1_1  Auvergne-Rhône-Alpes      None  FRA.1.3_1  Ardèche
# 3   FRA  France  FRA.1_1  Auvergne-Rhône-Alpes      None  FRA.1.4_1   Cantal
# 4   FRA  France  FRA.1_1  Auvergne-Rhône-Alpes      None  FRA.1.5_1    Drôme
#
#       VARNAME_2 NL_NAME_2       TYPE_2   ENGTYPE_2 CC_2 HASC_2  \
# 0          None      None  Département  Department   01  FR.AI
# 1  Basses-Alpes      None  Département  Department   03  FR.AL
# 2          None      None  Département  Department   07  FR.AH
# 3          None      None  Département  Department   15  FR.CL
# 4          None      None  Département  Department   26  FR.DM
#
#                                             geometry
# 0  POLYGON ((5.25563 45.78431, 5.24020 45.77737, ...
# 1  POLYGON ((2.38608 46.33197, 2.37061 46.31272, ...
# 2  POLYGON ((4.23405 44.27506, 4.21638 44.28904, ...
# 3  POLYGON ((2.85493 44.87431, 2.85140 44.87195, ...
# 4  POLYGON ((4.81214 44.24206, 4.81251 44.25802, ...

# %%
# get regions names for each state
regions_level2 = regions_level2[['NAME_1', 'NAME_2', 'geometry']]
regions_level2.columns = ['state', 'region', 'geometry']
regions_level2.head()
# Out:
#                   state   region  \
# 0  Auvergne-Rhône-Alpes      Ain
# 1  Auvergne-Rhône-Alpes   Allier
# 2  Auvergne-Rhône-Alpes  Ardèche
# 3  Auvergne-Rhône-Alpes   Cantal
# 4  Auvergne-Rhône-Alpes    Drôme
#
#                                             geometry
# 0  POLYGON ((5.25563 45.78431, 5.24020 45.77737, ...
# 1  POLYGON ((2.38608 46.33197, 2.37061 46.31272, ...
# 2  POLYGON ((4.23405 44.27506, 4.21638 44.28904, ...
# 3  POLYGON ((2.85493 44.87431, 2.85140 44.87195, ...
# 4  POLYGON ((4.81214 44.24206, 4.81251 44.25802, ...

# %%
# create a list with the names of the regions for a each state
states = regions_level2.groupby('state')['region'].apply(list).reset_index()
states
# Out:
#                          state  \
# 0         Auvergne-Rhône-Alpes
# 1      Bourgogne-Franche-Comté
# 2                     Bretagne
# 3          Centre-Val de Loire
# 4                        Corse
# 5                    Grand Est
# 6              Hauts-de-France
# 7                    Normandie
# 8           Nouvelle-Aquitaine
# 9                    Occitanie
# 10            Pays de la Loire
# 11  Provence-Alpes-Côte d'Azur
# 12               Île-de-France
#
#                                                region
# 0   [Ain, Allier, Ardèche, Cantal, Drôme, Haute-Lo...
# 1   [Côte-d'Or, Doubs, Haute-Saône, Jura, Nièvre, ...
# 2   [Côtes-d'Armor, Finistère, Ille-et-Vilaine, Mo...
# 3   [Cher, Eure-et-Loir, Indre, Indre-et-Loire, Lo...
# 4                         [Corse-du-Sud, Haute-Corse]
# 5   [Ardennes, Aube, Bas-Rhin, Haut-Rhin, Haute-Ma...
# 6           [Aisne, Nord, Oise, Pas-de-Calais, Somme]
# 7      [Calvados, Eure, Manche, Orne, Seine-Maritime]
# 8   [Charente, Charente-Maritime, Corrèze, Creuse,...
# 9   [Ariège, Aude, Aveyron, Gard, Gers, Haute-Garo...
# 10  [Loire-Atlantique, Maine-et-Loire, Mayenne, Sa...
# 11  [Alpes-de-Haute-Provence, Alpes-Maritimes, Bou...
# 12  [Essonne, Hauts-de-Seine, Paris, Seine-et-Marn...

# %%
# generate search queries for all types of farms in each regions of each state
farm_types = [
    "dairy farms",
    "poultry farms",
    "cattle farms",
    "livestock farms",
    "pig farms",
    "fish farms",
    "aquaculture farms",
    "egg farmers",
    "chicken hatchery",
    "shrimp farms",
    "seafood farms",
    "beef farms",
    "meat producer"
]

queries = []

for state in states['state']:
    for farm_type in farm_types:
        for region in states[states['state'] == state]['region'].values[0]:
        #for farm_type in farm_types:
            queries.append(f'{farm_type} in {region}, {state}')

# %%
#store the list in a pandas dataframe
queries_df = pd.DataFrame(queries, columns=['query'])
# divide the dataframe into each state based on the list of states
queries_df2 = queries_df.copy()
queries_df2['state'] = queries_df['query'].apply(lambda x: x.split(', ')[1])

queries_df2.to_csv('farm_queries.csv', index=False)
queries_df2.state.unique()
# Out:
# array(['Auvergne-Rhône-Alpes', 'Bourgogne-Franche-Comté', 'Bretagne',
#        'Centre-Val de Loire', 'Corse', 'Grand Est', 'Hauts-de-France',
#        'Normandie', 'Nouvelle-Aquitaine', 'Occitanie', 'Pays de la Loire',
#        "Provence-Alpes-Côte d'Azur", 'Île-de-France'], dtype=object)

# %%
import re

list_states = ['Auvergne-Rhône-Alpes', 'Bourgogne-Franche-Comté', 'Bretagne',
       'Centre-Val de Loire', 'Corse', 'Grand Est', 'Hauts-de-France',
       'Normandie', 'Nouvelle-Aquitaine', 'Occitanie', 'Pays de la Loire',
       "Provence-Alpes-Côte d'Azur", 'Île-de-France']

queries_df3 = queries_df2.copy()

# Loop through each state
for state in list_states:
    # Replace special characters and spaces with underscores
    state_file_name = re.sub(r'[^a-zA-Z0-9]', '_', state)

    # Filter DataFrame based on state and save only the queries for that state to a CSV file
    state_data = queries_df3[queries_df3['state'] == state]
    state_data.to_csv(f'farm_queries_{state_file_name}.csv', index=False)

    #queries_df3[queries_df3['state'] == state].to_csv(f'farm_queries_{state_file_name}.csv', index=False)

# %%
import re


list_states = ['Auvergne-Rhône-Alpes', 'Bourgogne-Franche-Comté', 'Bretagne',
       'Centre-Val de Loire', 'Corse', 'Grand Est', 'Hauts-de-France',
       'Normandie', 'Nouvelle-Aquitaine', 'Occitanie', 'Pays de la Loire',
       "Provence-Alpes-Côte d'Azur", 'Île-de-France']

queries_df3 = queries_df2.copy()

# Loop through each state
for state in list_states:
    # Replace special characters and spaces with underscores
    state_file_name = re.sub(r'[^a-zA-Z0-9]', '_', state)

    # Filter DataFrame based on state
    state_data = queries_df3[queries_df3['state'] == state]

    # Save only the queries for that state to a CSV file
    state_data.drop(columns=['state']).to_csv(f'farm_queries_{state_file_name}.csv', index=False)

# %%
df = pd.read_csv('farm_queries.csv')

# Generate queries dynamically from DataFrame to list format for web scraping
queries4 = []
for _, row in df.iterrows():
    query = f"{row['query']}"
    queries4.append(query)
    
queries4
# Out:
# ['dairy farms in Essonne, Île-de-France',
#  'dairy farms in Hauts-de-Seine, Île-de-France',
#  'dairy farms in Paris, Île-de-France',
#  'dairy farms in Seine-et-Marne, Île-de-France',
#  'dairy farms in Seine-Saint-Denis, Île-de-France',
#  "dairy farms in Val-d'Oise, Île-de-France",
#  'dairy farms in Val-de-Marne, Île-de-France',
#  'dairy farms in Yvelines, Île-de-France',
#  'poultry farms in Essonne, Île-de-France',
#  'poultry farms in Hauts-de-Seine, Île-de-France',
#  'poultry farms in Paris, Île-de-France',
#  'poultry farms in Seine-et-Marne, Île-de-France',
#  'poultry farms in Seine-Saint-Denis, Île-de-France',
#  "poultry farms in Val-d'Oise, Île-de-France",
#  'poultry farms in Val-de-Marne, Île-de-France',
#  'poultry farms in Yvelines, Île-de-France',
#  'cattle farms in Essonne, Île-de-France',
#  'cattle farms in Hauts-de-Seine, Île-de-France',
#  'cattle farms in Paris, Île-de-France',
#  'cattle farms in Seine-et-Marne, Île-de-France',
#  'cattle farms in Seine-Saint-Denis, Île-de-France',
#  "cattle farms in Val-d'Oise, Île-de-France",
#  'cattle farms in Val-de-Marne, Île-de-France',
#  'cattle farms in Yvelines, Île-de-France',
#  'livestock farms in Essonne, Île-de-France',
#  'livestock farms in Hauts-de-Seine, Île-de-France',
#  'livestock farms in Paris, Île-de-France',
#  'livestock farms in Seine-et-Marne, Île-de-France',
#  'livestock farms in Seine-Saint-Denis, Île-de-France',
#  "livestock farms in Val-d'Oise, Île-de-France",
#  'livestock farms in Val-de-Marne, Île-de-France',
#  'livestock farms in Yvelines, Île-de-France',
#  'pig farms in Essonne, Île-de-France',
#  'pig farms in Hauts-de-Seine, Île-de-France',
#  'pig farms in Paris, Île-de-France',
#  'pig farms in Seine-et-Marne, Île-de-France',
#  'pig farms in Seine-Saint-Denis, Île-de-France',
#  "pig farms in Val-d'Oise, Île-de-France",
#  'pig farms in Val-de-Marne, Île-de-France',
#  'pig farms in Yvelines, Île-de-France',
#  'fish farms in Essonne, Île-de-France',
#  'fish farms in Hauts-de-Seine, Île-de-France',
#  'fish farms in Paris, Île-de-France',
#  'fish farms in Seine-et-Marne, Île-de-France',
#  'fish farms in Seine-Saint-Denis, Île-de-France',
#  "fish farms in Val-d'Oise, Île-de-France",
#  'fish farms in Val-de-Marne, Île-de-France',
#  'fish farms in Yvelines, Île-de-France',
#  'aquaculture farms in Essonne, Île-de-France',
#  'aquaculture farms in Hauts-de-Seine, Île-de-France',
#  'aquaculture farms in Paris, Île-de-France',
#  'aquaculture farms in Seine-et-Marne, Île-de-France',
#  'aquaculture farms in Seine-Saint-Denis, Île-de-France',
#  "aquaculture farms in Val-d'Oise, Île-de-France",
#  'aquaculture farms in Val-de-Marne, Île-de-France',
#  'aquaculture farms in Yvelines, Île-de-France',
#  'egg farmers in Essonne, Île-de-France',
#  'egg farmers in Hauts-de-Seine, Île-de-France',
#  'egg farmers in Paris, Île-de-France',
#  'egg farmers in Seine-et-Marne, Île-de-France',
#  'egg farmers in Seine-Saint-Denis, Île-de-France',
#  "egg farmers in Val-d'Oise, Île-de-France",
#  'egg farmers in Val-de-Marne, Île-de-France',
#  'egg farmers in Yvelines, Île-de-France',
#  'chicken hatchery in Essonne, Île-de-France',
#  'chicken hatchery in Hauts-de-Seine, Île-de-France',
#  'chicken hatchery in Paris, Île-de-France',
#  'chicken hatchery in Seine-et-Marne, Île-de-France',
#  'chicken hatchery in Seine-Saint-Denis, Île-de-France',
#  "chicken hatchery in Val-d'Oise, Île-de-France",
#  'chicken hatchery in Val-de-Marne, Île-de-France',
#  'chicken hatchery in Yvelines, Île-de-France',
#  'shrimp farms in Essonne, Île-de-France',
#  'shrimp farms in Hauts-de-Seine, Île-de-France',
#  'shrimp farms in Paris, Île-de-France',
#  'shrimp farms in Seine-et-Marne, Île-de-France',
#  'shrimp farms in Seine-Saint-Denis, Île-de-France',
#  "shrimp farms in Val-d'Oise, Île-de-France",
#  'shrimp farms in Val-de-Marne, Île-de-France',
#  'shrimp farms in Yvelines, Île-de-France',
#  'seafood farms in Essonne, Île-de-France',
#  'seafood farms in Hauts-de-Seine, Île-de-France',
#  'seafood farms in Paris, Île-de-France',
#  'seafood farms in Seine-et-Marne, Île-de-France',
#  'seafood farms in Seine-Saint-Denis, Île-de-France',
#  "seafood farms in Val-d'Oise, Île-de-France",
#  'seafood farms in Val-de-Marne, Île-de-France',
#  'seafood farms in Yvelines, Île-de-France',
#  'beef farms in Essonne, Île-de-France',
#  'beef farms in Hauts-de-Seine, Île-de-France',
#  'beef farms in Paris, Île-de-France',
#  'beef farms in Seine-et-Marne, Île-de-France',
#  'beef farms in Seine-Saint-Denis, Île-de-France',
#  "beef farms in Val-d'Oise, Île-de-France",
#  'beef farms in Val-de-Marne, Île-de-France',
#  'beef farms in Yvelines, Île-de-France',
#  'meat producer in Essonne, Île-de-France',
#  'meat producer in Hauts-de-Seine, Île-de-France',
#  'meat producer in Paris, Île-de-France',
#  'meat producer in Seine-et-Marne, Île-de-France',
#  'meat producer in Seine-Saint-Denis, Île-de-France',
#  "meat producer in Val-d'Oise, Île-de-France",
#  'meat producer in Val-de-Marne, Île-de-France',
#  'meat producer in Yvelines, Île-de-France']
